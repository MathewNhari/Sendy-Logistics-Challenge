# %% [markdown]
# <a href="https://colab.research.google.com/github/MathewNhari/Sendy-Logistics-Challenge/blob/master/Zindi%20First%20Submission%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Importing Libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #**Importing Data**

# %%
riders = pd.read_csv('Riders.csv')
SampleSubmission = pd.read_csv('SampleSubmission.csv')
Test_df = pd.read_csv('Test.csv')
Train_df = pd.read_csv('Train.csv', parse_dates= ['Placement - Day of Month'])
VariableDefinitions = pd.read_csv('VariableDefinitions.csv')

# %%
VariableDefinitions
# Out:
#                                      Order No                Unique number identifying the order
# 0                                     User Id  Unique number identifying the customer on a pl...
# 1                                Vehicle Type  For this competition limited to bikes, however...
# 2                               Platform Type  Platform used to place the order, there are 4 ...
# 3                        Personal or Business                                      Customer type
# 4                    Placement - Day of Month                  Placement - Day of Month i.e 1-31
# 5                Placement - Weekday (Mo = 1)                   Placement - Weekday (Monday = 1)
# 6                            Placement - Time  Placement - Time - Time of day the order was p...
# 7                 Confirmation - Day of Month               Confirmation - Day of Month i.e 1-31
# 8             Confirmation - Weekday (Mo = 1)                Confirmation - Weekday (Monday = 1)
# 9                         Confirmation - Time  Confirmation - Time - Time of day the order wa...
# 10           Arrival at Pickup - Day of Month          Arrival at Pickup - Day of Month i.e 1-31
# 11       Arrival at Pickup - Weekday (Mo = 1)           Arrival at Pickup - Weekday (Monday = 1)
# 12                   Arrival at Pickup - Time  Time of day the the rider arrived at the locat...
# 13                      Pickup - Day of Month                     Pickup - Day of Month i.e 1-31
# 14                  Pickup - Weekday (Mo = 1)                      Pickup - Weekday (Monday = 1)
# 15                              Pickup - Time  Pickup - Time - Time of day the the rider pick...
# 16      Arrival at Destination - Day of Month        Arrival at Delivery - Day of Month i.e 1-31
# 17  Arrival at Destination - Weekday (Mo = 1)         Arrival at Delivery - Weekday (Monday = 1)
# 18              Arrival at Destination - Time  Arrival at Delivery Time - Time of day the rid...
# 19                              Distance (KM)            The distance from Pickup to Destination
# 20                                Temperature  Temperature at the time of order placement in ...
# 21               Precipitation in millimeters   Precipitation at the time of order placement ...
# 22                                 Pickup Lat                       Latitude of pick up location
# 23                                Pickup Long                      Longitude of pick up location
# 24                            Destination Lat                      Latitude of delivery location
# 25                           Destination Long                     Longitude of delivery location
# 26                                   Rider Id             ID of the Rider who accepted the order
# 27                Time from Pickup to Arrival  Time in seconds between 'Pickup' and 'Arrival ...
# 28                                        NaN                                                NaN
# 29                              Rider Metrics                                                NaN
# 30                                   Rider Id  Unique number identifying the rider (same as i...
# 31                               No_Of_Orders           Number of Orders the rider has delivered
# 32                                        Age  Number of days since the rider delivered the f...
# 33                             Average_Rating                        Average rating of the rider
# 34                              No_of_Ratings   Number of ratings the rider has received. Rat...

# %% [markdown]
# **Sample Submission**

# %%
SampleSubmission.head(1)
# Out:
#          Order_No  Time from Pickup to Arrival
# 0  Order_No_19248                        567.0

# %%
riders.head(1)
# Out:
#        Rider Id  No_Of_Orders   Age  Average_Rating  No_of_Ratings
# 0  Rider_Id_396          2946  2298            14.0           1159

# %%
Train_df.head(1)
# Out:
#         Order No      User Id  ...      Rider Id  Time from Pickup to Arrival
# 0  Order_No_4211  User_Id_633  ...  Rider_Id_432                          745
#
# [1 rows x 29 columns]

# %%
Train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21201 entries, 0 to 21200
# Data columns (total 29 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Order No                                   21201 non-null  object
#  1   User Id                                    21201 non-null  object
#  2   Vehicle Type                               21201 non-null  object
#  3   Platform Type                              21201 non-null  int64
#  4   Personal or Business                       21201 non-null  object
#  5   Placement - Day of Month                   21201 non-null  object
#  6   Placement - Weekday (Mo = 1)               21201 non-null  int64
#  7   Placement - Time                           21201 non-null  object
#  8   Confirmation - Day of Month                21201 non-null  int64
#  9   Confirmation - Weekday (Mo = 1)            21201 non-null  int64
#  10  Confirmation - Time                        21201 non-null  object
#  11  Arrival at Pickup - Day of Month           21201 non-null  int64
#  12  Arrival at Pickup - Weekday (Mo = 1)       21201 non-null  int64
#  13  Arrival at Pickup - Time                   21201 non-null  object
#  14  Pickup - Day of Month                      21201 non-null  int64
#  15  Pickup - Weekday (Mo = 1)                  21201 non-null  int64
#  16  Pickup - Time                              21201 non-null  object
#  17  Arrival at Destination - Day of Month      21201 non-null  int64
#  18  Arrival at Destination - Weekday (Mo = 1)  21201 non-null  int64
#  19  Arrival at Destination - Time              21201 non-null  object
#  20  Distance (KM)                              21201 non-null  int64
#  21  Temperature                                16835 non-null  float64
#  22  Precipitation in millimeters               552 non-null    float64
#  23  Pickup Lat                                 21201 non-null  float64
#  24  Pickup Long                                21201 non-null  float64
#  25  Destination Lat                            21201 non-null  float64
#  26  Destination Long                           21201 non-null  float64
#  27  Rider Id                                   21201 non-null  object
#  28  Time from Pickup to Arrival                21201 non-null  int64
# dtypes: float64(6), int64(12), object(11)
# memory usage: 4.7+ MB

# %%
#Train_df = Train_df.drop(['Precipitation in millimeters'], axis= 1)
#Test_df = Test_df.drop(['Precipitation in millimeters'], axis= 1)

# %% [markdown]
# # Joining Tables

# %%
Train_df = Train_df.merge(riders, on='Rider Id', how='left')
Test_df = Test_df.merge(riders, on='Rider Id', how='left')

# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# **Checking for Duplicates**

# %%
#No duplicate Data On Test Data
def Check_duplicates(df):
  duplicates = df.duplicated(subset = ['Order No'], keep = False)
  return df[duplicates]

# %%
#No duplicates 
Train_duplicates = Check_duplicates(Train_df)
Test_duplucates = Check_duplicates(Test_df)

# %% [markdown]
# **Changing into int data types

# %%
Train_df['Platform Type'] = Train_df['Platform Type'].astype('object')
Test_df['Platform Type'] = Test_df['Platform Type'].astype('object')       
Train_df['Placement - Day of Month'] = Train_df['Placement - Day of Month'].astype('int')
Test_df['Placement - Day of Month'] = Test_df['Placement - Day of Month'].astype('int')

# %% [markdown]
# **Dropping columns not in test Data**

# %%
def columnDrop(df,columns):
  df.drop(columns, axis=1,inplace=True)
  #df.set_index(['Order No'], inplace= True)
  return df

# %%
Drop_Train_Cols = ['Precipitation in millimeters', 'Arrival at Destination - Day of Month', 
                   'Arrival at Destination - Weekday (Mo = 1)', 'Arrival at Destination - Time']
Drop_Test_Cols =  ['Precipitation in millimeters']    
Test_df = columnDrop(Test_df,Drop_Test_Cols)
Train_df = columnDrop(Train_df,Drop_Train_Cols)

# %% [markdown]
# **Seperating Time**

# %%
def timeconvert(df,Time):
    df[Time] = df[Time].astype('datetime64')
    return df

# %%
Time_columns = ['Placement - Time', 'Confirmation - Time',
                'Arrival at Pickup - Time','Pickup - Time']
Train_df = timeconvert(Train_df,Time_columns)
Test_df = timeconvert(Test_df,Time_columns)

# %%
def SplitDatetime(df,columns):
  for item in columns:
    #df[item+'_day'] = pd.to_datetime(df[item]).dt.day
    df[item+'_hour'] = pd.to_datetime(df[item]).dt.hour
    df[item+'_minutes'] = pd.to_datetime(df[item]).dt.minute
    df[item+'_seconds'] = pd.to_datetime(df[item]).dt.second
  df.drop(columns,axis=1, inplace = True)
  return df

# %%
Time_columns = ['Placement - Time', 'Confirmation - Time',
                'Arrival at Pickup - Time','Pickup - Time']
Train_df = SplitDatetime(Train_df,Time_columns)
Test_df = SplitDatetime(Test_df,Time_columns)

# %%
Train_df.head(1)
# Out:
#         Order No      User Id  ... Pickup - Time_minutes Pickup - Time_seconds
# 0  Order_No_4211  User_Id_633  ...                    27                    30
#
# [1 rows x 37 columns]

# %% [markdown]
# **Taking Care of missing Data

# %%
from sklearn.impute import SimpleImputer

def missingData(df,columns):
  imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
  imputer.fit(df[columns])
  df[columns] = imputer.transform(df[columns])
  return df

# %%
columns = ['Temperature']
Test_df = missingData(Test_df,columns)
Train_df = missingData(Train_df,columns)

# %%
Train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21201 entries, 0 to 21200
# Data columns (total 37 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Order No                              21201 non-null  object
#  1   User Id                               21201 non-null  object
#  2   Vehicle Type                          21201 non-null  object
#  3   Platform Type                         21201 non-null  object
#  4   Personal or Business                  21201 non-null  object
#  5   Placement - Day of Month              21201 non-null  int64
#  6   Placement - Weekday (Mo = 1)          21201 non-null  int64
#  7   Confirmation - Day of Month           21201 non-null  int64
#  8   Confirmation - Weekday (Mo = 1)       21201 non-null  int64
#  9   Arrival at Pickup - Day of Month      21201 non-null  int64
#  10  Arrival at Pickup - Weekday (Mo = 1)  21201 non-null  int64
#  11  Pickup - Day of Month                 21201 non-null  int64
#  12  Pickup - Weekday (Mo = 1)             21201 non-null  int64
#  13  Distance (KM)                         21201 non-null  int64
#  14  Temperature                           21201 non-null  float64
#  15  Pickup Lat                            21201 non-null  float64
#  16  Pickup Long                           21201 non-null  float64
#  17  Destination Lat                       21201 non-null  float64
#  18  Destination Long                      21201 non-null  float64
#  19  Rider Id                              21201 non-null  object
#  20  Time from Pickup to Arrival           21201 non-null  int64
#  21  No_Of_Orders                          21201 non-null  int64
#  22  Age                                   21201 non-null  int64
#  23  Average_Rating                        21201 non-null  float64
#  24  No_of_Ratings                         21201 non-null  int64
#  25  Placement - Time_hour                 21201 non-null  int64
#  26  Placement - Time_minutes              21201 non-null  int64
#  27  Placement - Time_seconds              21201 non-null  int64
#  28  Confirmation - Time_hour              21201 non-null  int64
#  29  Confirmation - Time_minutes           21201 non-null  int64
#  30  Confirmation - Time_seconds           21201 non-null  int64
#  31  Arrival at Pickup - Time_hour         21201 non-null  int64
#  32  Arrival at Pickup - Time_minutes      21201 non-null  int64
#  33  Arrival at Pickup - Time_seconds      21201 non-null  int64
#  34  Pickup - Time_hour                    21201 non-null  int64
#  35  Pickup - Time_minutes                 21201 non-null  int64
#  36  Pickup - Time_seconds                 21201 non-null  int64
# dtypes: float64(6), int64(25), object(6)
# memory usage: 6.1+ MB

# %% [markdown]
# # **Feature Engineering**

# %% [markdown]
# **Get Dummy Variables**

# %%
def dummy_encoder(df, cols):
  dummies = pd.get_dummies(df,columns= cols,drop_first = True)
  merged = pd.concat([df,dummies],axis='columns')
  final = merged.drop(cols, axis = 1)
  return dummies

# %%
cols = ['Platform Type','Personal or Business', 'Placement - Weekday (Mo = 1)',
        'Confirmation - Weekday (Mo = 1)','Pickup - Weekday (Mo = 1)','Rider Id','Vehicle Type','User Id']
Train_df = dummy_encoder(Train_df, cols)
Test_df = dummy_encoder(Test_df, cols)
Test_df.head(1)
# Out:
#          Order No  ...  User Id_User_Id_996
# 0  Order_No_19248  ...                    0
#
# [1 rows x 2487 columns]

# %%
Train_df.head(1)
# Out:
#         Order No  ...  User Id_User_Id_999
# 0  Order_No_4211  ...                    0
#
# [1 rows x 4159 columns]

# %% [markdown]
# **Variable Selection by Correlation and Significance**

# %%
Train = Train_df.drop(['Order No'],axis=1)
Test = Test_df.drop(['Order No'],axis=1)

# %%
# Calculate correlations between predictor variables and the response variable
corrs = Train.corr()['Time from Pickup to Arrival'].sort_values(ascending=False)

# %%
from scipy.stats import pearsonr

# Build a dictionary of correlation coefficients and p-values
dict_cp = {}

column_titles = [col for col in corrs.index if col!= 'Time from Pickup to Arrival']
for col in column_titles:
    p_val = round(pearsonr(Train[col], Train['Time from Pickup to Arrival'])[1],6)
    dict_cp[col] = {'Correlation_Coefficient':corrs[col],
                    'P_Value':p_val}

df_cp = pd.DataFrame(dict_cp).T
df_cp_sorted = df_cp.sort_values('P_Value')
df_cp_sorted[df_cp_sorted['P_Value']<0.1]
# Out:
# ['Distance (KM)',
#  'Destination Long',
#  'Rider Id_Rider_Id_519',
#  'User Id_User_Id_2982',
#  'Pickup Long',
#  'Rider Id_Rider_Id_831',
#  'User Id_User_Id_1271',
#  'User Id_User_Id_1245',
#  'User Id_User_Id_3599',
#  'User Id_User_Id_136',
#  'User Id_User_Id_658',
#  'User Id_User_Id_552',
#  'Rider Id_Rider_Id_268',
#  'User Id_User_Id_1927',
#  'User Id_User_Id_2018',
#  'Rider Id_Rider_Id_697',
#  'Rider Id_Rider_Id_883',
#  'User Id_User_Id_3262',
#  'Rider Id_Rider_Id_554',
#  'User Id_User_Id_2931',
#  'Rider Id_Rider_Id_447',
#  'Rider Id_Rider_Id_155',
#  'Rider Id_Rider_Id_418',
#  'User Id_User_Id_3547',
#  'Rider Id_Rider_Id_498',
#  'User Id_User_Id_84',
#  'User Id_User_Id_2132',
#  'User Id_User_Id_3434',
#  'Rider Id_Rider_Id_680',
#  'User Id_User_Id_1384',
#  'Rider Id_Rider_Id_64',
#  'Rider Id_Rider_Id_332',
#  'Rider Id_Rider_Id_787',
#  'User Id_User_Id_3238',
#  'User Id_User_Id_187',
#  'Rider Id_Rider_Id_244',
#  'User Id_User_Id_842',
#  'User Id_User_Id_3586',
#  'User Id_User_Id_1051',
#  'User Id_User_Id_1179',
#  'User Id_User_Id_3246',
#  'User Id_User_Id_2370',
#  'User Id_User_Id_1780',
#  'User Id_User_Id_2869',
#  'Rider Id_Rider_Id_6',
#  'User Id_User_Id_620',
#  'Rider Id_Rider_Id_457',
#  'Rider Id_Rider_Id_928',
#  'User Id_User_Id_982',
#  'User Id_User_Id_1524',
#  'User Id_User_Id_2509',
#  'User Id_User_Id_1282',
#  'Rider Id_Rider_Id_730',
#  'User Id_User_Id_2335',
#  'Rider Id_Rider_Id_292',
#  'Rider Id_Rider_Id_543',
#  'Rider Id_Rider_Id_303',
#  'User Id_User_Id_3698',
#  'User Id_User_Id_571',
#  'User Id_User_Id_1473',
#  'Rider Id_Rider_Id_800',
#  'Rider Id_Rider_Id_12',
#  'User Id_User_Id_2995',
#  'Rider Id_Rider_Id_404',
#  'User Id_User_Id_1259',
#  'Rider Id_Rider_Id_772',
#  'User Id_User_Id_1383',
#  'User Id_User_Id_3517',
#  'User Id_User_Id_439',
#  'User Id_User_Id_2640',
#  'User Id_User_Id_510',
#  'User Id_User_Id_900',
#  'Rider Id_Rider_Id_248',
#  'Rider Id_Rider_Id_391',
#  'User Id_User_Id_911',
#  'Rider Id_Rider_Id_271',
#  'User Id_User_Id_1121',
#  'User Id_User_Id_1258',
#  'User Id_User_Id_3398',
#  'Rider Id_Rider_Id_755',
#  'User Id_User_Id_2331',
#  'User Id_User_Id_2837',
#  'Rider Id_Rider_Id_542',
#  'User Id_User_Id_2174',
#  'User Id_User_Id_1128',
#  'User Id_User_Id_360',
#  'User Id_User_Id_2716',
#  'Rider Id_Rider_Id_387',
#  'Rider Id_Rider_Id_699',
#  'Rider Id_Rider_Id_48',
#  'User Id_User_Id_105',
#  'Rider Id_Rider_Id_938',
#  'User Id_User_Id_3629',
#  'Rider Id_Rider_Id_106',
#  'Rider Id_Rider_Id_198',
#  'User Id_User_Id_3043',
#  'Rider Id_Rider_Id_478',
#  'User Id_User_Id_461',
#  'User Id_User_Id_3097',
#  'Rider Id_Rider_Id_718',
#  'User Id_User_Id_2306',
#  'Rider Id_Rider_Id_618',
#  'User Id_User_Id_1189',
#  'User Id_User_Id_2916',
#  'User Id_User_Id_1761',
#  'User Id_User_Id_1359',
#  'Rider Id_Rider_Id_792',
#  'Rider Id_Rider_Id_222',
#  'Rider Id_Rider_Id_32',
#  'User Id_User_Id_3270',
#  'Rider Id_Rider_Id_532',
#  'Rider Id_Rider_Id_272',
#  'User Id_User_Id_2570',
#  'Rider Id_Rider_Id_821',
#  'User Id_User_Id_718',
#  'User Id_User_Id_3340',
#  'Rider Id_Rider_Id_581',
#  'User Id_User_Id_720',
#  'Rider Id_Rider_Id_202',
#  'User Id_User_Id_115',
#  'Rider Id_Rider_Id_267',
#  'Rider Id_Rider_Id_362',
#  'Rider Id_Rider_Id_203',
#  'User Id_User_Id_1410',
#  'User Id_User_Id_1781',
#  'User Id_User_Id_323',
#  'User Id_User_Id_2198',
#  'User Id_User_Id_814',
#  'User Id_User_Id_1506',
#  'User Id_User_Id_170',
#  'User Id_User_Id_1958',
#  'User Id_User_Id_1595',
#  'User Id_User_Id_739',
#  'User Id_User_Id_2559',
#  'User Id_User_Id_141',
#  'User Id_User_Id_722',
#  'Rider Id_Rider_Id_305',
#  'User Id_User_Id_3626',
#  'Rider Id_Rider_Id_661',
#  'User Id_User_Id_1990',
#  'User Id_User_Id_527',
#  'Rider Id_Rider_Id_131',
#  'User Id_User_Id_744',
#  'Rider Id_Rider_Id_599',
#  'Rider Id_Rider_Id_226',
#  'User Id_User_Id_432',
#  'User Id_User_Id_1304',
#  'Rider Id_Rider_Id_441',
#  'Rider Id_Rider_Id_805',
#  'User Id_User_Id_1831',
#  'Rider Id_Rider_Id_200',
#  'Rider Id_Rider_Id_593',
#  'User Id_User_Id_2658',
#  'User Id_User_Id_3108',
#  'Rider Id_Rider_Id_654',
#  'User Id_User_Id_1415',
#  'User Id_User_Id_733',
#  'Rider Id_Rider_Id_548',
#  'User Id_User_Id_3491',
#  'Rider Id_Rider_Id_572',
#  'User Id_User_Id_2897',
#  'Rider Id_Rider_Id_101',
#  'User Id_User_Id_3173',
#  'User Id_User_Id_598',
#  'Rider Id_Rider_Id_936',
#  'User Id_User_Id_2102',
#  'Pickup - Weekday (Mo = 1)_5',
#  'Placement - Weekday (Mo = 1)_5',
#  'Confirmation - Weekday (Mo = 1)_5',
#  'Rider Id_Rider_Id_815',
#  'Rider Id_Rider_Id_109',
#  'User Id_User_Id_3722',
#  'User Id_User_Id_2008',
#  'Rider Id_Rider_Id_233',
#  'User Id_User_Id_2961',
#  'User Id_User_Id_116',
#  'Rider Id_Rider_Id_30',
#  'User Id_User_Id_704',
#  'User Id_User_Id_162',
#  'User Id_User_Id_1877',
#  'User Id_User_Id_2677',
#  'User Id_User_Id_125',
#  'User Id_User_Id_985',
#  'Rider Id_Rider_Id_700',
#  'User Id_User_Id_1544',
#  'Rider Id_Rider_Id_677',
#  'Rider Id_Rider_Id_238',
#  'Rider Id_Rider_Id_488',
#  'User Id_User_Id_755',
#  'Rider Id_Rider_Id_235',
#  'Rider Id_Rider_Id_431',
#  'Rider Id_Rider_Id_584',
#  'User Id_User_Id_910',
#  'User Id_User_Id_2874',
#  'Rider Id_Rider_Id_668',
#  'User Id_User_Id_485',
#  'User Id_User_Id_2853',
#  'User Id_User_Id_2373',
#  'User Id_User_Id_3569',
#  'Rider Id_Rider_Id_59',
#  'User Id_User_Id_3052',
#  'User Id_User_Id_1878',
#  'Rider Id_Rider_Id_533',
#  'User Id_User_Id_3590',
#  'User Id_User_Id_1261',
#  'User Id_User_Id_2147',
#  'User Id_User_Id_506',
#  'User Id_User_Id_3152',
#  'User Id_User_Id_838',
#  'User Id_User_Id_3565',
#  'User Id_User_Id_3681',
#  'User Id_User_Id_2121',
#  'User Id_User_Id_1648',
#  'Arrival at Pickup - Time_hour',
#  'User Id_User_Id_3147',
#  'Rider Id_Rider_Id_876',
#  'Rider Id_Rider_Id_328',
#  'Rider Id_Rider_Id_844',
#  'Rider Id_Rider_Id_33',
#  'User Id_User_Id_2537',
#  'User Id_User_Id_677',
#  'Rider Id_Rider_Id_187',
#  'Rider Id_Rider_Id_95',
#  'User Id_User_Id_1942',
#  'User Id_User_Id_1081',
#  'User Id_User_Id_2896',
#  'Rider Id_Rider_Id_934',
#  'Rider Id_Rider_Id_94',
#  'User Id_User_Id_3373',
#  'Rider Id_Rider_Id_279',
#  'User Id_User_Id_3348',
#  'User Id_User_Id_1397',
#  'User Id_User_Id_410',
#  'User Id_User_Id_2735',
#  'User Id_User_Id_2833',
#  'User Id_User_Id_477',
#  'User Id_User_Id_2271',
#  'Rider Id_Rider_Id_419',
#  'Rider Id_Rider_Id_734',
#  'User Id_User_Id_3406',
#  'User Id_User_Id_918',
#  'Rider Id_Rider_Id_470',
#  'User Id_User_Id_1217',
#  'User Id_User_Id_2093',
#  'User Id_User_Id_352',
#  'User Id_User_Id_3446',
#  'Rider Id_Rider_Id_301',
#  'Rider Id_Rider_Id_644',
#  'User Id_User_Id_1561',
#  'User Id_User_Id_1952',
#  'Confirmation - Weekday (Mo = 1)_2',
#  'Pickup - Weekday (Mo = 1)_2',
#  'User Id_User_Id_3542',
#  'User Id_User_Id_560',
#  'User Id_User_Id_2199',
#  'Placement - Weekday (Mo = 1)_2',
#  'User Id_User_Id_268',
#  'User Id_User_Id_1087',
#  'User Id_User_Id_3362',
#  'User Id_User_Id_2504',
#  'User Id_User_Id_2829',
#  'Rider Id_Rider_Id_401',
#  'User Id_User_Id_1585',
#  'User Id_User_Id_2542',
#  'User Id_User_Id_1569',
#  'User Id_User_Id_2779',
#  'User Id_User_Id_1851',
#  'Rider Id_Rider_Id_42',
#  'User Id_User_Id_186',
#  'Rider Id_Rider_Id_44',
#  'User Id_User_Id_3707',
#  'Rider Id_Rider_Id_911',
#  'User Id_User_Id_3080',
#  'User Id_User_Id_1705',
#  'Rider Id_Rider_Id_672',
#  'User Id_User_Id_2190',
#  'User Id_User_Id_3232',
#  'Rider Id_Rider_Id_385',
#  'User Id_User_Id_2879',
#  'User Id_User_Id_1471',
#  'Rider Id_Rider_Id_192',
#  'User Id_User_Id_2256',
#  'Rider Id_Rider_Id_560',
#  'User Id_User_Id_3234',
#  'User Id_User_Id_394',
#  'User Id_User_Id_2568',
#  'User Id_User_Id_2534',
#  'Rider Id_Rider_Id_753',
#  'User Id_User_Id_2726',
#  'User Id_User_Id_503',
#  'Rider Id_Rider_Id_939',
#  'User Id_User_Id_2704',
#  'User Id_User_Id_2762',
#  'Rider Id_Rider_Id_660',
#  'Rider Id_Rider_Id_452',
#  'User Id_User_Id_15',
#  'User Id_User_Id_3444',
#  'User Id_User_Id_3031',
#  'User Id_User_Id_2245',
#  'User Id_User_Id_858',
#  'User Id_User_Id_258',
#  'Rider Id_Rider_Id_520',
#  'Rider Id_Rider_Id_868',
#  'User Id_User_Id_3413',
#  'Rider Id_Rider_Id_373',
#  'User Id_User_Id_2823',
#  'Rider Id_Rider_Id_918',
#  'User Id_User_Id_691',
#  'User Id_User_Id_791',
#  'User Id_User_Id_2738',
#  'Rider Id_Rider_Id_789',
#  'Rider Id_Rider_Id_357',
#  'Rider Id_Rider_Id_223',
#  'User Id_User_Id_2851',
#  'Rider Id_Rider_Id_884',
#  'User Id_User_Id_1541',
#  'User Id_User_Id_3122',
#  'Rider Id_Rider_Id_63',
#  'User Id_User_Id_1597',
#  'Rider Id_Rider_Id_75',
#  'Rider Id_Rider_Id_691',
#  'User Id_User_Id_782',
#  'User Id_User_Id_3649',
#  'Rider Id_Rider_Id_296',
#  'User Id_User_Id_1214',
#  'User Id_User_Id_2483',
#  'Rider Id_Rider_Id_824',
#  'User Id_User_Id_2270',
#  'Rider Id_Rider_Id_83',
#  'Rider Id_Rider_Id_890',
#  'User Id_User_Id_3095',
#  'User Id_User_Id_3020',
#  'User Id_User_Id_138',
#  'Rider Id_Rider_Id_711',
#  'User Id_User_Id_954',
#  'User Id_User_Id_2827',
#  'User Id_User_Id_1398',
#  'Rider Id_Rider_Id_761',
#  'User Id_User_Id_2045',
#  'Rider Id_Rider_Id_38',
#  'User Id_User_Id_2603',
#  'User Id_User_Id_3154',
#  'User Id_User_Id_2063',
#  'User Id_User_Id_3525',
#  'User Id_User_Id_3598',
#  'User Id_User_Id_2260',
#  'User Id_User_Id_1389',
#  'Rider Id_Rider_Id_300',
#  'User Id_User_Id_2096',
#  'User Id_User_Id_681',
#  'User Id_User_Id_207',
#  'User Id_User_Id_2020',
#  'User Id_User_Id_757',
#  'Rider Id_Rider_Id_867',
#  'User Id_User_Id_324',
#  'User Id_User_Id_1482',
#  'Rider Id_Rider_Id_162',
#  'Rider Id_Rider_Id_802',
#  'Rider Id_Rider_Id_799',
#  'User Id_User_Id_1526',
#  'User Id_User_Id_848',
#  'User Id_User_Id_1688',
#  'User Id_User_Id_1001',
#  'User Id_User_Id_379',
#  'User Id_User_Id_3013',
#  'User Id_User_Id_1502',
#  'Personal or Business_Personal',
#  'User Id_User_Id_3582',
#  'User Id_User_Id_2877',
#  'Rider Id_Rider_Id_231',
#  'User Id_User_Id_1460',
#  'User Id_User_Id_3212',
#  'User Id_User_Id_2273',
#  'User Id_User_Id_1966',
#  'Rider Id_Rider_Id_625',
#  'Rider Id_Rider_Id_123',
#  'Rider Id_Rider_Id_793',
#  'User Id_User_Id_1621',
#  'User Id_User_Id_111',
#  'User Id_User_Id_3669',
#  'Rider Id_Rider_Id_395',
#  'Rider Id_Rider_Id_13',
#  'User Id_User_Id_2576',
#  'User Id_User_Id_411',
#  'User Id_User_Id_244',
#  'User Id_User_Id_206',
#  'Rider Id_Rider_Id_26',
#  'User Id_User_Id_3',
#  'User Id_User_Id_286',
#  'User Id_User_Id_380',
#  'User Id_User_Id_759',
#  'Rider Id_Rider_Id_771',
#  'User Id_User_Id_3622',
#  'User Id_User_Id_203',
#  'User Id_User_Id_3583',
#  'User Id_User_Id_639',
#  'User Id_User_Id_3177',
#  'User Id_User_Id_1486',
#  'User Id_User_Id_2304',
#  'User Id_User_Id_1288',
#  'User Id_User_Id_1534',
#  'User Id_User_Id_3206',
#  'Rider Id_Rider_Id_421',
#  'Rider Id_Rider_Id_686',
#  'User Id_User_Id_2362',
#  'Rider Id_Rider_Id_573',
#  'User Id_User_Id_2505',
#  'User Id_User_Id_3321',
#  'User Id_User_Id_2673',
#  'User Id_User_Id_420',
#  'User Id_User_Id_936',
#  'Rider Id_Rider_Id_579',
#  'Rider Id_Rider_Id_778',
#  'Rider Id_Rider_Id_859',
#  'User Id_User_Id_579',
#  'Rider Id_Rider_Id_810',
#  'Rider Id_Rider_Id_346',
#  'User Id_User_Id_1903',
#  'User Id_User_Id_3567',
#  'User Id_User_Id_2809',
#  'Rider Id_Rider_Id_420',
#  'User Id_User_Id_2777',
#  'Pickup - Time_minutes',
#  'Rider Id_Rider_Id_234',
#  'Rider Id_Rider_Id_580',
#  'User Id_User_Id_99',
#  'Rider Id_Rider_Id_565',
#  'User Id_User_Id_2130',
#  'User Id_User_Id_2713',
#  'User Id_User_Id_2639',
#  'User Id_User_Id_649',
#  'User Id_User_Id_269',
#  'User Id_User_Id_3200',
#  'User Id_User_Id_2112',
#  'Placement - Weekday (Mo = 1)_7',
#  'Confirmation - Weekday (Mo = 1)_7',
#  'Pickup - Weekday (Mo = 1)_7',
#  'User Id_User_Id_2772',
#  'User Id_User_Id_1419',
#  'User Id_User_Id_765',
#  'User Id_User_Id_1589',
#  'Rider Id_Rider_Id_371',
#  'User Id_User_Id_265',
#  'Rider Id_Rider_Id_181',
#  'User Id_User_Id_3378',
#  'User Id_User_Id_3106',
#  'Rider Id_Rider_Id_948',
#  'User Id_User_Id_6',
#  'User Id_User_Id_761',
#  'User Id_User_Id_51',
#  'User Id_User_Id_418',
#  'Rider Id_Rider_Id_121',
#  'User Id_User_Id_3768',
#  'Rider Id_Rider_Id_493',
#  'Rider Id_Rider_Id_880',
#  'User Id_User_Id_3070',
#  'User Id_User_Id_2651',
#  'Rider Id_Rider_Id_118',
#  'User Id_User_Id_3343',
#  'User Id_User_Id_1004',
#  'Rider Id_Rider_Id_596',
#  'User Id_User_Id_1985',
#  'User Id_User_Id_833',
#  'User Id_User_Id_3171',
#  'User Id_User_Id_1873',
#  'User Id_User_Id_426',
#  'Rider Id_Rider_Id_34',
#  'User Id_User_Id_1874',
#  'User Id_User_Id_528',
#  'User Id_User_Id_2714',
#  'User Id_User_Id_1446',
#  'User Id_User_Id_577',
#  'User Id_User_Id_221',
#  'User Id_User_Id_1182',
#  'Rider Id_Rider_Id_230',
#  'User Id_User_Id_62',
#  'User Id_User_Id_1845',
#  'User Id_User_Id_2289',
#  'Rider Id_Rider_Id_168',
#  'Rider Id_Rider_Id_946',
#  'Rider Id_Rider_Id_530',
#  'Rider Id_Rider_Id_458',
#  'Rider Id_Rider_Id_504',
#  'Rider Id_Rider_Id_631',
#  'User Id_User_Id_75',
#  'User Id_User_Id_3145',
#  'User Id_User_Id_3113',
#  'User Id_User_Id_3273',
#  'User Id_User_Id_419',
#  'User Id_User_Id_631',
#  'User Id_User_Id_2453',
#  'User Id_User_Id_1559',
#  'Rider Id_Rider_Id_630',
#  'User Id_User_Id_2866',
#  'User Id_User_Id_1754',
#  'Rider Id_Rider_Id_703',
#  'Rider Id_Rider_Id_25',
#  'User Id_User_Id_3008',
#  'User Id_User_Id_2403',
#  'Rider Id_Rider_Id_931',
#  'User Id_User_Id_522',
#  'User Id_User_Id_534',
#  'Rider Id_Rider_Id_612',
#  'Rider Id_Rider_Id_311',
#  'Rider Id_Rider_Id_184',
#  'User Id_User_Id_112',
#  'Rider Id_Rider_Id_917',
#  'User Id_User_Id_2545',
#  'User Id_User_Id_235',
#  'User Id_User_Id_3123',
#  'Rider Id_Rider_Id_58',
#  'Rider Id_Rider_Id_66',
#  'User Id_User_Id_1655',
#  'User Id_User_Id_472',
#  'User Id_User_Id_313',
#  'User Id_User_Id_3415',
#  'User Id_User_Id_2125',
#  'Rider Id_Rider_Id_351',
#  'User Id_User_Id_1225',
#  'User Id_User_Id_2192',
#  'User Id_User_Id_63',
#  'User Id_User_Id_329',
#  'User Id_User_Id_1880',
#  'User Id_User_Id_2317',
#  'Rider Id_Rider_Id_760',
#  'User Id_User_Id_2858',
#  'User Id_User_Id_2923',
#  'User Id_User_Id_3554',
#  'Rider Id_Rider_Id_325',
#  'Rider Id_Rider_Id_384',
#  'User Id_User_Id_2242',
#  'User Id_User_Id_288',
#  'Rider Id_Rider_Id_887',
#  'User Id_User_Id_2006',
#  'Rider Id_Rider_Id_492',
#  'Pickup - Time_hour',
#  'User Id_User_Id_2523',
#  'User Id_User_Id_1909',
#  'User Id_User_Id_1701',
#  'Rider Id_Rider_Id_471',
#  'User Id_User_Id_3661',
#  'User Id_User_Id_2904',
#  'Rider Id_Rider_Id_340',
#  'Rider Id_Rider_Id_847',
#  'User Id_User_Id_3432',
#  'Rider Id_Rider_Id_114',
#  'Rider Id_Rider_Id_105',
#  'Rider Id_Rider_Id_435',
#  'User Id_User_Id_1047',
#  'Rider Id_Rider_Id_416',
#  'Rider Id_Rider_Id_715',
#  'Rider Id_Rider_Id_199',
#  'Rider Id_Rider_Id_739',
#  'User Id_User_Id_299',
#  'User Id_User_Id_3562',
#  'User Id_User_Id_995',
#  'User Id_User_Id_1588',
#  'User Id_User_Id_3482',
#  'Arrival at Pickup - Time_minutes',
#  'User Id_User_Id_375',
#  'User Id_User_Id_695',
#  'User Id_User_Id_383',
#  'User Id_User_Id_2408',
#  'Rider Id_Rider_Id_712',
#  'User Id_User_Id_3523',
#  'User Id_User_Id_2781',
#  'User Id_User_Id_3633',
#  'User Id_User_Id_3426',
#  'User Id_User_Id_1089',
#  'Rider Id_Rider_Id_741',
#  'Rider Id_Rider_Id_46',
#  'User Id_User_Id_3040',
#  'Rider Id_Rider_Id_949',
#  'Rider Id_Rider_Id_302',
#  'Rider Id_Rider_Id_469',
#  'Arrival at Pickup - Weekday (Mo = 1)',
#  'User Id_User_Id_430',
#  'User Id_User_Id_665',
#  'User Id_User_Id_1750',
#  'Rider Id_Rider_Id_582',
#  'Rider Id_Rider_Id_916',
#  'User Id_User_Id_166',
#  'User Id_User_Id_1676',
#  'User Id_User_Id_259',
#  'Rider Id_Rider_Id_725',
#  'User Id_User_Id_1042',
#  'Rider Id_Rider_Id_605',
#  'User Id_User_Id_1719',
#  'Rider Id_Rider_Id_827',
#  'User Id_User_Id_1658',
#  'User Id_User_Id_1855',
#  'User Id_User_Id_2634',
#  'User Id_User_Id_3204',
#  'User Id_User_Id_1186',
#  'User Id_User_Id_1660',
#  'User Id_User_Id_3514',
#  'Rider Id_Rider_Id_804',
#  'User Id_User_Id_473',
#  'User Id_User_Id_3625',
#  'Rider Id_Rider_Id_791',
#  'User Id_User_Id_2596',
#  'User Id_User_Id_1525',
#  'Rider Id_Rider_Id_614',
#  'User Id_User_Id_1746',
#  'User Id_User_Id_2805',
#  'User Id_User_Id_591',
#  'User Id_User_Id_2628',
#  'User Id_User_Id_198',
#  'Rider Id_Rider_Id_204',
#  'User Id_User_Id_3245',
#  'User Id_User_Id_3758',
#  'User Id_User_Id_2346',
#  'Rider Id_Rider_Id_47',
#  'User Id_User_Id_1531',
#  'User Id_User_Id_909',
#  'User Id_User_Id_1532',
#  'Rider Id_Rider_Id_149',
#  'User Id_User_Id_3326',
#  'Rider Id_Rider_Id_609',
#  'User Id_User_Id_3750',
#  'User Id_User_Id_3436',
#  'Rider Id_Rider_Id_512',
#  'User Id_User_Id_3214',
#  'User Id_User_Id_3580',
#  'User Id_User_Id_67',
#  'User Id_User_Id_1774',
#  'User Id_User_Id_2380',
#  'User Id_User_Id_2103',
#  'User Id_User_Id_3224',
#  'User Id_User_Id_1972',
#  'User Id_User_Id_956',
#  'User Id_User_Id_3676',
#  'User Id_User_Id_654',
#  'User Id_User_Id_2666',
#  'User Id_User_Id_3269',
#  'User Id_User_Id_2770',
#  'User Id_User_Id_101',
#  'User Id_User_Id_1109',
#  'User Id_User_Id_535',
#  'User Id_User_Id_2180',
#  'User Id_User_Id_2265',
#  'Rider Id_Rider_Id_594',
#  'User Id_User_Id_844',
#  'Rider Id_Rider_Id_11',
#  'User Id_User_Id_147',
#  'Rider Id_Rider_Id_553',
#  'User Id_User_Id_3272',
#  'User Id_User_Id_1879',
#  'User Id_User_Id_3447',
#  'User Id_User_Id_2079',
#  'User Id_User_Id_2201',
#  'User Id_User_Id_347',
#  'Rider Id_Rider_Id_549',
#  'User Id_User_Id_3250',
#  'Rider Id_Rider_Id_422',
#  'User Id_User_Id_2582',
#  'Rider Id_Rider_Id_908',
#  'User Id_User_Id_2182',
#  'Rider Id_Rider_Id_287',
#  'User Id_User_Id_2605',
#  'User Id_User_Id_1991',
#  'Rider Id_Rider_Id_490',
#  'Rider Id_Rider_Id_148',
#  'User Id_User_Id_2168',
#  'User Id_User_Id_685',
#  'Rider Id_Rider_Id_479',
#  'User Id_User_Id_3184',
#  'Rider Id_Rider_Id_43',
#  'User Id_User_Id_353',
#  'Rider Id_Rider_Id_937',
#  'User Id_User_Id_2399',
#  'Rider Id_Rider_Id_502',
#  'Rider Id_Rider_Id_442',
#  'User Id_User_Id_3135',
#  'User Id_User_Id_1324',
#  'Rider Id_Rider_Id_846',
#  'Rider Id_Rider_Id_350',
#  'Rider Id_Rider_Id_108',
#  'User Id_User_Id_1681',
#  'User Id_User_Id_1647',
#  'User Id_User_Id_82',
#  'User Id_User_Id_1858',
#  'User Id_User_Id_1586',
#  'User Id_User_Id_226',
#  'Rider Id_Rider_Id_516',
#  'User Id_User_Id_2510',
#  'User Id_User_Id_570',
#  'User Id_User_Id_3068',
#  'Rider Id_Rider_Id_693',
#  'User Id_User_Id_3609',
#  'User Id_User_Id_2884',
#  'User Id_User_Id_2828',
#  'User Id_User_Id_3595',
#  'User Id_User_Id_2254',
#  'User Id_User_Id_25',
#  'User Id_User_Id_823',
#  'Rider Id_Rider_Id_316',
#  'Rider Id_Rider_Id_465',
#  'User Id_User_Id_3683',
#  'User Id_User_Id_1221',
#  'Rider Id_Rider_Id_569',
#  'Rider Id_Rider_Id_92',
#  'User Id_User_Id_201',
#  'User Id_User_Id_435',
#  'Rider Id_Rider_Id_275',
#  'Rider Id_Rider_Id_175',
#  'User Id_User_Id_793',
#  'User Id_User_Id_1797',
#  'User Id_User_Id_2685',
#  'User Id_User_Id_602',
#  'User Id_User_Id_2657',
#  'User Id_User_Id_2689',
#  'User Id_User_Id_1474',
#  'Rider Id_Rider_Id_334',
#  'User Id_User_Id_2379',
#  'User Id_User_Id_1720',
#  'User Id_User_Id_421',
#  'User Id_User_Id_3700',
#  'User Id_User_Id_736',
#  'User Id_User_Id_20',
#  'User Id_User_Id_771',
#  'User Id_User_Id_1846',
#  'Rider Id_Rider_Id_306',
#  'User Id_User_Id_2156',
#  'User Id_User_Id_303',
#  'User Id_User_Id_2101',
#  'User Id_User_Id_459',
#  'User Id_User_Id_415',
#  'Rider Id_Rider_Id_480',
#  'User Id_User_Id_3747',
#  'Rider Id_Rider_Id_326',
#  'User Id_User_Id_545',
#  'User Id_User_Id_687',
#  'User Id_User_Id_1740',
#  'User Id_User_Id_320',
#  'Rider Id_Rider_Id_82',
#  'User Id_User_Id_1961',
#  'User Id_User_Id_662',
#  'User Id_User_Id_3091',
#  'Rider Id_Rider_Id_521',
#  'User Id_User_Id_2895',
#  'User Id_User_Id_2580',
#  'User Id_User_Id_2920',
#  'Pickup - Weekday (Mo = 1)_3',
#  'Confirmation - Weekday (Mo = 1)_3',
#  'Placement - Weekday (Mo = 1)_3',
#  'Rider Id_Rider_Id_81',
#  'User Id_User_Id_3732',
#  'User Id_User_Id_561',
#  'User Id_User_Id_3602',
#  'User Id_User_Id_3252',
#  'User Id_User_Id_1361',
#  'User Id_User_Id_864',
#  'Rider Id_Rider_Id_571',
#  'User Id_User_Id_1105',
#  'User Id_User_Id_1333',
#  'Rider Id_Rider_Id_31',
#  'Rider Id_Rider_Id_321',
#  'User Id_User_Id_645',
#  'User Id_User_Id_605',
#  'User Id_User_Id_2285',
#  'User Id_User_Id_293',
#  'Rider Id_Rider_Id_689',
#  'User Id_User_Id_3217',
#  'Rider Id_Rider_Id_265',
#  'User Id_User_Id_3658',
#  'User Id_User_Id_3372',
#  'User Id_User_Id_3356',
#  'User Id_User_Id_2281',
#  'User Id_User_Id_3027',
#  'User Id_User_Id_515',
#  'User Id_User_Id_2258',
#  'Rider Id_Rider_Id_451',
#  'User Id_User_Id_847',
#  'User Id_User_Id_1697',
#  'User Id_User_Id_1478',
#  'User Id_User_Id_345',
#  'User Id_User_Id_2175',
#  'User Id_User_Id_213',
#  'Rider Id_Rider_Id_627',
#  'User Id_User_Id_13',
#  'Rider Id_Rider_Id_143',
#  'User Id_User_Id_2165',
#  'User Id_User_Id_1594',
#  'User Id_User_Id_1630',
#  'Rider Id_Rider_Id_511',
#  'User Id_User_Id_3651',
#  'User Id_User_Id_3687',
#  'Rider Id_Rider_Id_89',
#  'User Id_User_Id_530',
#  'Rider Id_Rider_Id_796',
#  'Rider Id_Rider_Id_177',
#  'Rider Id_Rider_Id_702',
#  'User Id_User_Id_494',
#  'User Id_User_Id_3316',
#  'User Id_User_Id_2031',
#  'Rider Id_Rider_Id_347',
#  'User Id_User_Id_686',
#  'Rider Id_Rider_Id_557',
#  'Rider Id_Rider_Id_608',
#  'User Id_User_Id_2419',
#  'User Id_User_Id_65',
#  'User Id_User_Id_196',
#  'User Id_User_Id_1236',
#  'User Id_User_Id_3287',
#  'User Id_User_Id_3486',
#  'User Id_User_Id_228',
#  'User Id_User_Id_878',
#  'Rider Id_Rider_Id_440',
#  'User Id_User_Id_2388',
#  'User Id_User_Id_429',
#  'User Id_User_Id_1837',
#  'Rider Id_Rider_Id_195',
#  'Rider Id_Rider_Id_93',
#  'User Id_User_Id_2040',
#  'User Id_User_Id_1069',
#  'User Id_User_Id_49',
#  'User Id_User_Id_3297',
#  'User Id_User_Id_103',
#  'User Id_User_Id_3363',
#  'Rider Id_Rider_Id_675',
#  'User Id_User_Id_3249',
#  'User Id_User_Id_676',
#  'Rider Id_Rider_Id_423',
#  'User Id_User_Id_3261',
#  'User Id_User_Id_2985',
#  'User Id_User_Id_1323',
#  'User Id_User_Id_962',
#  'User Id_User_Id_2494',
#  'User Id_User_Id_760',
#  'User Id_User_Id_59',
#  'User Id_User_Id_2796',
#  'User Id_User_Id_2727',
#  'User Id_User_Id_3112',
#  'User Id_User_Id_3450',
#  'User Id_User_Id_1430',
#  'User Id_User_Id_3774',
#  'User Id_User_Id_3714',
#  'User Id_User_Id_516',
#  'Rider Id_Rider_Id_254',
#  'User Id_User_Id_1195',
#  'User Id_User_Id_3524',
#  'Rider Id_Rider_Id_165',
#  'User Id_User_Id_3377',
#  'User Id_User_Id_3414',
#  'User Id_User_Id_3367',
#  'User Id_User_Id_467',
#  'User Id_User_Id_1257',
#  'Rider Id_Rider_Id_496',
#  'User Id_User_Id_23',
#  'Rider Id_Rider_Id_682',
#  'User Id_User_Id_3365',
#  'User Id_User_Id_496',
#  'User Id_User_Id_3751',
#  'User Id_User_Id_2642',
#  'User Id_User_Id_1351',
#  'User Id_User_Id_1379',
#  'Rider Id_Rider_Id_99',
#  'Rider Id_Rider_Id_500',
#  'User Id_User_Id_3674',
#  'User Id_User_Id_865',
#  'User Id_User_Id_929',
#  'User Id_User_Id_2282',
#  'Rider Id_Rider_Id_578',
#  'User Id_User_Id_1953',
#  'Rider Id_Rider_Id_257',
#  'Rider Id_Rider_Id_856',
#  'Rider Id_Rider_Id_117',
#  'User Id_User_Id_3663',
#  'User Id_User_Id_1367',
#  'User Id_User_Id_637',
#  'User Id_User_Id_2548',
#  'Rider Id_Rider_Id_487',
#  'User Id_User_Id_562',
#  'Rider Id_Rider_Id_411',
#  'User Id_User_Id_3320',
#  'Rider Id_Rider_Id_482',
#  'User Id_User_Id_569',
#  'Rider Id_Rider_Id_769',
#  'User Id_User_Id_1663',
#  'Rider Id_Rider_Id_942',
#  'Rider Id_Rider_Id_651',
#  'Rider Id_Rider_Id_190',
#  'User Id_User_Id_272',
#  'User Id_User_Id_2247',
#  'Rider Id_Rider_Id_218',
#  'User Id_User_Id_3729',
#  'User Id_User_Id_3684',
#  'User Id_User_Id_636',
#  'User Id_User_Id_1433',
#  'User Id_User_Id_1291',
#  'User Id_User_Id_1893',
#  'Rider Id_Rider_Id_60',
#  'User Id_User_Id_933',
#  'User Id_User_Id_1530',
#  'User Id_User_Id_2825',
#  'User Id_User_Id_1908',
#  'User Id_User_Id_2070',
#  'Rider Id_Rider_Id_513',
#  'User Id_User_Id_392',
#  'User Id_User_Id_537',
#  'User Id_User_Id_2562',
#  'User Id_User_Id_1888',
#  'Rider Id_Rider_Id_120',
#  'User Id_User_Id_1262',
#  'User Id_User_Id_580',
#  'User Id_User_Id_1043',
#  'User Id_User_Id_1752',
#  'Rider Id_Rider_Id_899',
#  'User Id_User_Id_1685',
#  'User Id_User_Id_1583',
#  'User Id_User_Id_2042',
#  'User Id_User_Id_1607',
#  'User Id_User_Id_1919',
#  'Rider Id_Rider_Id_817',
#  'User Id_User_Id_2930',
#  'User Id_User_Id_1914',
#  'User Id_User_Id_72',
#  'Rider Id_Rider_Id_784',
#  'User Id_User_Id_3341',
#  'Rider Id_Rider_Id_837',
#  'Rider Id_Rider_Id_870',
#  'Confirmation - Time_hour',
#  'Rider Id_Rider_Id_430',
#  'User Id_User_Id_2792',
#  'Rider Id_Rider_Id_308',
#  'User Id_User_Id_3593',
#  'Rider Id_Rider_Id_877',
#  'User Id_User_Id_1177',
#  'User Id_User_Id_220',
#  'Rider Id_Rider_Id_4',
#  'User Id_User_Id_2989',
#  'User Id_User_Id_2878',
#  'Rider Id_Rider_Id_773',
#  'User Id_User_Id_2255',
#  'User Id_User_Id_2821',
#  'User Id_User_Id_703',
#  'User Id_User_Id_1118',
#  'User Id_User_Id_1062',
#  'User Id_User_Id_617',
#  'User Id_User_Id_318',
#  'User Id_User_Id_2532',
#  'Rider Id_Rider_Id_626',
#  'User Id_User_Id_3448',
#  'User Id_User_Id_990',
#  'User Id_User_Id_2305',
#  'User Id_User_Id_2071',
#  'User Id_User_Id_3443',
#  'User Id_User_Id_3376',
#  'User Id_User_Id_1166',
#  'User Id_User_Id_1208',
#  'User Id_User_Id_2550',
#  'Rider Id_Rider_Id_537',
#  'Rider Id_Rider_Id_17',
#  'User Id_User_Id_1741',
#  'Rider Id_Rider_Id_329',
#  'User Id_User_Id_1546',
#  'Rider Id_Rider_Id_159',
#  'User Id_User_Id_28',
#  'User Id_User_Id_3299',
#  'User Id_User_Id_770',
#  'User Id_User_Id_239',
#  'User Id_User_Id_2057',
#  'User Id_User_Id_960',
#  'User Id_User_Id_2091',
#  'Rider Id_Rider_Id_895',
#  'User Id_User_Id_3708',
#  'Temperature',
#  'User Id_User_Id_3371',
#  'User Id_User_Id_47',
#  'User Id_User_Id_2123',
#  'User Id_User_Id_3302',
#  'User Id_User_Id_884',
#  'User Id_User_Id_2457',
#  'User Id_User_Id_3128',
#  'Rider Id_Rider_Id_779',
#  'User Id_User_Id_1539',
#  'User Id_User_Id_3306',
#  'User Id_User_Id_2918',
#  'User Id_User_Id_1171',
#  'Rider Id_Rider_Id_588',
#  'User Id_User_Id_1192',
#  'User Id_User_Id_2393',
#  'User Id_User_Id_2291',
#  'User Id_User_Id_297',
#  'No_of_Ratings',
#  'User Id_User_Id_276',
#  'User Id_User_Id_3323',
#  'User Id_User_Id_2097',
#  'User Id_User_Id_2229',
#  'User Id_User_Id_2355',
#  'User Id_User_Id_1345',
#  'User Id_User_Id_3630',
#  'User Id_User_Id_3141',
#  'User Id_User_Id_2849',
#  'User Id_User_Id_2522',
#  'Rider Id_Rider_Id_372',
#  'User Id_User_Id_3656',
#  'User Id_User_Id_928',
#  'User Id_User_Id_1944',
#  ...]

# %%
# The dependent variable remains the same:
y_data = Train['Time from Pickup to Arrival'] 

# Model building - Independent Variable (IV) DataFrame
X_names = list(df_cp[df_cp['P_Value'] < 0.05].index)
X_data = Train[X_names]
X_names
#Test_data = Test[X_names]
# Out:
# ['Distance (KM)',
#  'Destination Long',
#  'Rider Id_Rider_Id_519',
#  'User Id_User_Id_2982',
#  'Pickup Long',
#  'Rider Id_Rider_Id_831',
#  'User Id_User_Id_1271',
#  'User Id_User_Id_1245',
#  'User Id_User_Id_3599',
#  'User Id_User_Id_136',
#  'User Id_User_Id_658',
#  'User Id_User_Id_552',
#  'Rider Id_Rider_Id_268',
#  'User Id_User_Id_1927',
#  'User Id_User_Id_2018',
#  'Rider Id_Rider_Id_697',
#  'Rider Id_Rider_Id_883',
#  'User Id_User_Id_3262',
#  'Rider Id_Rider_Id_554',
#  'User Id_User_Id_2931',
#  'Rider Id_Rider_Id_447',
#  'Rider Id_Rider_Id_155',
#  'Rider Id_Rider_Id_418',
#  'User Id_User_Id_3547',
#  'Rider Id_Rider_Id_498',
#  'User Id_User_Id_84',
#  'User Id_User_Id_2132',
#  'User Id_User_Id_3434',
#  'Rider Id_Rider_Id_680',
#  'User Id_User_Id_1384',
#  'Rider Id_Rider_Id_64',
#  'Rider Id_Rider_Id_332',
#  'Rider Id_Rider_Id_787',
#  'User Id_User_Id_3238',
#  'User Id_User_Id_187',
#  'Rider Id_Rider_Id_244',
#  'User Id_User_Id_842',
#  'User Id_User_Id_3586',
#  'User Id_User_Id_1051',
#  'User Id_User_Id_1179',
#  'User Id_User_Id_3246',
#  'User Id_User_Id_2370',
#  'User Id_User_Id_1780',
#  'User Id_User_Id_2869',
#  'Rider Id_Rider_Id_6',
#  'User Id_User_Id_620',
#  'Rider Id_Rider_Id_457',
#  'Rider Id_Rider_Id_928',
#  'User Id_User_Id_982',
#  'User Id_User_Id_1524',
#  'User Id_User_Id_2509',
#  'User Id_User_Id_1282',
#  'Rider Id_Rider_Id_730',
#  'User Id_User_Id_2335',
#  'Rider Id_Rider_Id_292',
#  'Rider Id_Rider_Id_543',
#  'Rider Id_Rider_Id_303',
#  'User Id_User_Id_3698',
#  'User Id_User_Id_571',
#  'User Id_User_Id_1473',
#  'Rider Id_Rider_Id_800',
#  'Rider Id_Rider_Id_12',
#  'User Id_User_Id_2995',
#  'Rider Id_Rider_Id_404',
#  'User Id_User_Id_1259',
#  'Rider Id_Rider_Id_772',
#  'User Id_User_Id_1383',
#  'User Id_User_Id_3517',
#  'User Id_User_Id_439',
#  'User Id_User_Id_2640',
#  'User Id_User_Id_510',
#  'User Id_User_Id_900',
#  'Rider Id_Rider_Id_248',
#  'Rider Id_Rider_Id_391',
#  'User Id_User_Id_911',
#  'Rider Id_Rider_Id_271',
#  'User Id_User_Id_1121',
#  'User Id_User_Id_1258',
#  'User Id_User_Id_3398',
#  'Rider Id_Rider_Id_755',
#  'User Id_User_Id_2331',
#  'User Id_User_Id_2837',
#  'Rider Id_Rider_Id_542',
#  'User Id_User_Id_2174',
#  'User Id_User_Id_1128',
#  'User Id_User_Id_360',
#  'User Id_User_Id_2716',
#  'Rider Id_Rider_Id_387',
#  'Rider Id_Rider_Id_699',
#  'Rider Id_Rider_Id_48',
#  'User Id_User_Id_105',
#  'Rider Id_Rider_Id_938',
#  'User Id_User_Id_3629',
#  'Rider Id_Rider_Id_106',
#  'Rider Id_Rider_Id_198',
#  'User Id_User_Id_3043',
#  'Rider Id_Rider_Id_478',
#  'User Id_User_Id_461',
#  'User Id_User_Id_3097',
#  'Rider Id_Rider_Id_718',
#  'User Id_User_Id_2306',
#  'Rider Id_Rider_Id_618',
#  'User Id_User_Id_1189',
#  'User Id_User_Id_2916',
#  'User Id_User_Id_1761',
#  'User Id_User_Id_1359',
#  'Rider Id_Rider_Id_792',
#  'Rider Id_Rider_Id_222',
#  'Rider Id_Rider_Id_32',
#  'User Id_User_Id_3270',
#  'Rider Id_Rider_Id_532',
#  'Rider Id_Rider_Id_272',
#  'User Id_User_Id_2570',
#  'Rider Id_Rider_Id_821',
#  'User Id_User_Id_718',
#  'User Id_User_Id_3340',
#  'Rider Id_Rider_Id_581',
#  'User Id_User_Id_720',
#  'Rider Id_Rider_Id_202',
#  'User Id_User_Id_115',
#  'Rider Id_Rider_Id_267',
#  'Rider Id_Rider_Id_362',
#  'Rider Id_Rider_Id_203',
#  'User Id_User_Id_1410',
#  'User Id_User_Id_1781',
#  'User Id_User_Id_323',
#  'User Id_User_Id_2198',
#  'User Id_User_Id_814',
#  'User Id_User_Id_1506',
#  'User Id_User_Id_170',
#  'User Id_User_Id_1958',
#  'User Id_User_Id_1595',
#  'User Id_User_Id_739',
#  'User Id_User_Id_2559',
#  'User Id_User_Id_141',
#  'User Id_User_Id_722',
#  'Rider Id_Rider_Id_305',
#  'User Id_User_Id_3626',
#  'Rider Id_Rider_Id_661',
#  'User Id_User_Id_1990',
#  'User Id_User_Id_527',
#  'Rider Id_Rider_Id_131',
#  'User Id_User_Id_744',
#  'Rider Id_Rider_Id_599',
#  'Rider Id_Rider_Id_226',
#  'User Id_User_Id_432',
#  'User Id_User_Id_1304',
#  'Rider Id_Rider_Id_441',
#  'Rider Id_Rider_Id_805',
#  'User Id_User_Id_1831',
#  'Rider Id_Rider_Id_200',
#  'Rider Id_Rider_Id_593',
#  'User Id_User_Id_2658',
#  'User Id_User_Id_3108',
#  'Rider Id_Rider_Id_654',
#  'User Id_User_Id_1415',
#  'User Id_User_Id_733',
#  'Rider Id_Rider_Id_548',
#  'User Id_User_Id_3491',
#  'Rider Id_Rider_Id_572',
#  'User Id_User_Id_2897',
#  'Rider Id_Rider_Id_101',
#  'User Id_User_Id_3173',
#  'User Id_User_Id_598',
#  'Rider Id_Rider_Id_936',
#  'User Id_User_Id_2102',
#  'Pickup - Weekday (Mo = 1)_5',
#  'Placement - Weekday (Mo = 1)_5',
#  'Confirmation - Weekday (Mo = 1)_5',
#  'Rider Id_Rider_Id_815',
#  'Rider Id_Rider_Id_109',
#  'User Id_User_Id_3722',
#  'User Id_User_Id_2008',
#  'Rider Id_Rider_Id_233',
#  'User Id_User_Id_2961',
#  'User Id_User_Id_116',
#  'Rider Id_Rider_Id_30',
#  'User Id_User_Id_704',
#  'User Id_User_Id_162',
#  'User Id_User_Id_1877',
#  'User Id_User_Id_2677',
#  'User Id_User_Id_125',
#  'User Id_User_Id_985',
#  'Rider Id_Rider_Id_700',
#  'User Id_User_Id_1544',
#  'Rider Id_Rider_Id_677',
#  'Rider Id_Rider_Id_238',
#  'Rider Id_Rider_Id_488',
#  'User Id_User_Id_755',
#  'Rider Id_Rider_Id_235',
#  'Rider Id_Rider_Id_431',
#  'Rider Id_Rider_Id_584',
#  'User Id_User_Id_910',
#  'User Id_User_Id_2874',
#  'Rider Id_Rider_Id_668',
#  'User Id_User_Id_485',
#  'User Id_User_Id_2853',
#  'User Id_User_Id_2373',
#  'User Id_User_Id_3569',
#  'Rider Id_Rider_Id_59',
#  'User Id_User_Id_3052',
#  'User Id_User_Id_1878',
#  'Rider Id_Rider_Id_533',
#  'User Id_User_Id_3590',
#  'User Id_User_Id_1261',
#  'User Id_User_Id_2147',
#  'User Id_User_Id_506',
#  'User Id_User_Id_3152',
#  'User Id_User_Id_838',
#  'User Id_User_Id_3565',
#  'User Id_User_Id_3681',
#  'User Id_User_Id_2121',
#  'User Id_User_Id_1648',
#  'Arrival at Pickup - Time_hour',
#  'User Id_User_Id_3147',
#  'Rider Id_Rider_Id_876',
#  'Rider Id_Rider_Id_328',
#  'Rider Id_Rider_Id_844',
#  'Rider Id_Rider_Id_33',
#  'User Id_User_Id_2537',
#  'User Id_User_Id_677',
#  'Rider Id_Rider_Id_187',
#  'Rider Id_Rider_Id_95',
#  'User Id_User_Id_1942',
#  'User Id_User_Id_1081',
#  'User Id_User_Id_2896',
#  'Rider Id_Rider_Id_934',
#  'Rider Id_Rider_Id_94',
#  'User Id_User_Id_3373',
#  'Rider Id_Rider_Id_279',
#  'User Id_User_Id_3348',
#  'User Id_User_Id_1397',
#  'User Id_User_Id_410',
#  'User Id_User_Id_2735',
#  'User Id_User_Id_2833',
#  'User Id_User_Id_477',
#  'User Id_User_Id_2271',
#  'Rider Id_Rider_Id_419',
#  'Rider Id_Rider_Id_734',
#  'User Id_User_Id_3406',
#  'User Id_User_Id_918',
#  'Rider Id_Rider_Id_470',
#  'User Id_User_Id_1217',
#  'User Id_User_Id_2093',
#  'User Id_User_Id_352',
#  'User Id_User_Id_3446',
#  'Rider Id_Rider_Id_301',
#  'Rider Id_Rider_Id_644',
#  'User Id_User_Id_1561',
#  'User Id_User_Id_1952',
#  'Confirmation - Weekday (Mo = 1)_2',
#  'Pickup - Weekday (Mo = 1)_2',
#  'User Id_User_Id_3542',
#  'User Id_User_Id_560',
#  'User Id_User_Id_2199',
#  'Placement - Weekday (Mo = 1)_2',
#  'User Id_User_Id_268',
#  'User Id_User_Id_1087',
#  'User Id_User_Id_3362',
#  'User Id_User_Id_2504',
#  'User Id_User_Id_2829',
#  'Rider Id_Rider_Id_401',
#  'User Id_User_Id_1585',
#  'User Id_User_Id_2542',
#  'User Id_User_Id_1569',
#  'User Id_User_Id_2779',
#  'User Id_User_Id_1851',
#  'Rider Id_Rider_Id_42',
#  'User Id_User_Id_186',
#  'Rider Id_Rider_Id_44',
#  'User Id_User_Id_3707',
#  'Rider Id_Rider_Id_911',
#  'User Id_User_Id_3080',
#  'User Id_User_Id_1705',
#  'Rider Id_Rider_Id_672',
#  'User Id_User_Id_2190',
#  'User Id_User_Id_3232',
#  'Rider Id_Rider_Id_385',
#  'User Id_User_Id_2879',
#  'User Id_User_Id_1471',
#  'Rider Id_Rider_Id_192',
#  'User Id_User_Id_2256',
#  'Rider Id_Rider_Id_560',
#  'User Id_User_Id_3234',
#  'User Id_User_Id_394',
#  'User Id_User_Id_2568',
#  'User Id_User_Id_2534',
#  'Rider Id_Rider_Id_753',
#  'User Id_User_Id_2726',
#  'User Id_User_Id_503',
#  'Rider Id_Rider_Id_939',
#  'User Id_User_Id_2704',
#  'User Id_User_Id_2762',
#  'Rider Id_Rider_Id_660',
#  'Rider Id_Rider_Id_452',
#  'User Id_User_Id_15',
#  'User Id_User_Id_3444',
#  'User Id_User_Id_3031',
#  'User Id_User_Id_2245',
#  'User Id_User_Id_858',
#  'User Id_User_Id_258',
#  'Rider Id_Rider_Id_520',
#  'Rider Id_Rider_Id_868',
#  'User Id_User_Id_3413',
#  'Rider Id_Rider_Id_373',
#  'User Id_User_Id_2823',
#  'Rider Id_Rider_Id_918',
#  'User Id_User_Id_691',
#  'User Id_User_Id_791',
#  'User Id_User_Id_2738',
#  'Rider Id_Rider_Id_789',
#  'Rider Id_Rider_Id_357',
#  'Rider Id_Rider_Id_223',
#  'User Id_User_Id_2851',
#  'Rider Id_Rider_Id_884',
#  'User Id_User_Id_1541',
#  'User Id_User_Id_3122',
#  'Rider Id_Rider_Id_63',
#  'User Id_User_Id_1597',
#  'Rider Id_Rider_Id_75',
#  'Rider Id_Rider_Id_691',
#  'User Id_User_Id_782',
#  'User Id_User_Id_3649',
#  'Rider Id_Rider_Id_296',
#  'User Id_User_Id_1214',
#  'User Id_User_Id_2483',
#  'Rider Id_Rider_Id_824',
#  'User Id_User_Id_2270',
#  'Rider Id_Rider_Id_83',
#  'Rider Id_Rider_Id_890',
#  'User Id_User_Id_3095',
#  'User Id_User_Id_3020',
#  'User Id_User_Id_138',
#  'Rider Id_Rider_Id_711',
#  'User Id_User_Id_954',
#  'User Id_User_Id_2827',
#  'User Id_User_Id_1398',
#  'Rider Id_Rider_Id_761',
#  'User Id_User_Id_2045',
#  'Rider Id_Rider_Id_38',
#  'User Id_User_Id_2603',
#  'User Id_User_Id_3154',
#  'User Id_User_Id_2063',
#  'User Id_User_Id_3525',
#  'User Id_User_Id_3598',
#  'User Id_User_Id_2260',
#  'User Id_User_Id_1389',
#  'Rider Id_Rider_Id_300',
#  'User Id_User_Id_2096',
#  'User Id_User_Id_681',
#  'User Id_User_Id_207',
#  'User Id_User_Id_2020',
#  'User Id_User_Id_757',
#  'Rider Id_Rider_Id_867',
#  'User Id_User_Id_324',
#  'User Id_User_Id_1482',
#  'Rider Id_Rider_Id_162',
#  'Rider Id_Rider_Id_802',
#  'Rider Id_Rider_Id_799',
#  'User Id_User_Id_1526',
#  'User Id_User_Id_848',
#  'User Id_User_Id_1688',
#  'User Id_User_Id_1001',
#  'User Id_User_Id_3203',
#  'Rider Id_Rider_Id_491',
#  'User Id_User_Id_1850',
#  'Rider Id_Rider_Id_489',
#  'Rider Id_Rider_Id_655',
#  'User Id_User_Id_2212',
#  'User Id_User_Id_1246',
#  'Rider Id_Rider_Id_242',
#  'Rider Id_Rider_Id_383',
#  'Rider Id_Rider_Id_809',
#  'Rider Id_Rider_Id_795',
#  'User Id_User_Id_2350',
#  'Rider Id_Rider_Id_405',
#  'User Id_User_Id_647',
#  'Rider Id_Rider_Id_678',
#  'Rider Id_Rider_Id_598',
#  'Rider Id_Rider_Id_783',
#  'Confirmation - Day of Month',
#  'Arrival at Pickup - Day of Month',
#  'Pickup - Day of Month',
#  'Placement - Day of Month',
#  'Rider Id_Rider_Id_245',
#  'Rider Id_Rider_Id_390',
#  'Rider Id_Rider_Id_634',
#  'User Id_User_Id_173',
#  'Rider Id_Rider_Id_206',
#  'User Id_User_Id_1120',
#  'Rider Id_Rider_Id_249',
#  'Rider Id_Rider_Id_336',
#  'Rider Id_Rider_Id_2',
#  'Rider Id_Rider_Id_843',
#  'Rider Id_Rider_Id_85',
#  'Rider Id_Rider_Id_575',
#  'User Id_User_Id_3560',
#  'User Id_User_Id_1642',
#  'Rider Id_Rider_Id_744',
#  'Rider Id_Rider_Id_379',
#  'User Id_User_Id_970',
#  'Rider Id_Rider_Id_566',
#  'Rider Id_Rider_Id_312',
#  'User Id_User_Id_2391',
#  'Rider Id_Rider_Id_358',
#  'Rider Id_Rider_Id_314',
#  'Rider Id_Rider_Id_61',
#  'Rider Id_Rider_Id_116',
#  'Rider Id_Rider_Id_205',
#  'Rider Id_Rider_Id_531',
#  'Rider Id_Rider_Id_88',
#  'Rider Id_Rider_Id_875',
#  'User Id_User_Id_3017',
#  'User Id_User_Id_1932',
#  'Rider Id_Rider_Id_714',
#  'User Id_User_Id_302',
#  'Rider Id_Rider_Id_15',
#  'Rider Id_Rider_Id_535',
#  'Rider Id_Rider_Id_446',
#  'Rider Id_Rider_Id_658',
#  'Rider Id_Rider_Id_111',
#  'Rider Id_Rider_Id_652',
#  'User Id_User_Id_2528',
#  'User Id_User_Id_635',
#  'User Id_User_Id_2987',
#  'User Id_User_Id_2330',
#  'Rider Id_Rider_Id_438',
#  'Rider Id_Rider_Id_453',
#  'Rider Id_Rider_Id_318',
#  'Rider Id_Rider_Id_607',
#  'Rider Id_Rider_Id_49',
#  'Rider Id_Rider_Id_100',
#  'Rider Id_Rider_Id_842',
#  'Rider Id_Rider_Id_407',
#  'Rider Id_Rider_Id_259',
#  'Rider Id_Rider_Id_921',
#  'Rider Id_Rider_Id_484',
#  'User Id_User_Id_1146',
#  'User Id_User_Id_81',
#  'User Id_User_Id_1075',
#  'User Id_User_Id_2383',
#  'Rider Id_Rider_Id_818',
#  'User Id_User_Id_346',
#  'Rider Id_Rider_Id_857',
#  'User Id_User_Id_190',
#  'User Id_User_Id_412',
#  'Rider Id_Rider_Id_193',
#  'User Id_User_Id_2521',
#  'User Id_User_Id_540',
#  'User Id_User_Id_1809',
#  'User Id_User_Id_3689',
#  'Rider Id_Rider_Id_119',
#  'User Id_User_Id_2030',
#  'Rider Id_Rider_Id_403',
#  'Rider Id_Rider_Id_881',
#  'User Id_User_Id_246',
#  'User Id_User_Id_706',
#  'Rider Id_Rider_Id_103',
#  'User Id_User_Id_238',
#  'Rider Id_Rider_Id_754',
#  'User Id_User_Id_3521',
#  'Rider Id_Rider_Id_179',
#  'Placement - Weekday (Mo = 1)_6',
#  'Pickup - Weekday (Mo = 1)_6',
#  'Confirmation - Weekday (Mo = 1)_6',
#  'Rider Id_Rider_Id_427',
#  'Rider Id_Rider_Id_855',
#  'Rider Id_Rider_Id_953',
#  'User Id_User_Id_1527',
#  'Rider Id_Rider_Id_613',
#  'Rider Id_Rider_Id_726',
#  'Rider Id_Rider_Id_927',
#  'User Id_User_Id_53',
#  'User Id_User_Id_3557',
#  'Rider Id_Rider_Id_291',
#  'Rider Id_Rider_Id_70',
#  'User Id_User_Id_1209',
#  'User Id_User_Id_1363',
#  'Rider Id_Rider_Id_41',
#  'User Id_User_Id_3201',
#  'Rider Id_Rider_Id_137',
#  'Rider Id_Rider_Id_472',
#  'Rider Id_Rider_Id_576',
#  'No_Of_Orders',
#  'User Id_User_Id_3149',
#  'Average_Rating',
#  'User Id_User_Id_3291',
#  'User Id_User_Id_1500',
#  'User Id_User_Id_517',
#  'Rider Id_Rider_Id_239',
#  'Rider Id_Rider_Id_51',
#  'User Id_User_Id_3283',
#  'Rider Id_Rider_Id_619',
#  'Rider Id_Rider_Id_10',
#  'User Id_User_Id_868',
#  'Rider Id_Rider_Id_39',
#  'Pickup Lat',
#  'Rider Id_Rider_Id_515',
#  'Destination Lat',
#  'User Id_User_Id_633',
#  'User Id_User_Id_393']

# %%
Test_data = Test_df[X_names]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-0a526f833243> in <module>()
# ----> 1 Test_data = Test_df[X_names]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1644             if not (self.name == "loc" and not raise_missing):
#    1645                 not_found = list(set(key) - set(ax))
# -> 1646                 raise KeyError(f"{not_found} not in index")
#    1647
#    1648             # we skip the warning on Categorical/Interval
#
# KeyError: "['User Id_User_Id_1595', 'User Id_User_Id_1761', 'User Id_User_Id_911', 'User Id_User_Id_848', 'User Id_User_Id_3707', 'User Id_User_Id_1383', 'User Id_User_Id_3362', 'User Id_User_Id_1398', 'User Id_User_Id_1359', 'User Id_User_Id_900', 'User Id_User_Id_3722', 'User Id_User_Id_1128', 'User Id_User_Id_3681', 'User Id_User_Id_720', 'User Id_User_Id_485', 'User Id_User_Id_3043', 'User Id_User_Id_3373', 'User Id_User_Id_3270', 'User Id_User_Id_1952', 'User Id_User_Id_2045', 'User Id_User_Id_3152', 'User Id_User_Id_3444', 'User Id_User_Id_207', 'User Id_User_Id_1569', 'User Id_User_Id_3626', 'User Id_User_Id_3649', 'User Id_User_Id_2370', 'User Id_User_Id_620', 'User Id_User_Id_1121', 'User Id_User_Id_2704', 'User Id_User_Id_1541', 'User Id_User_Id_2373', 'User Id_User_Id_3542', 'User Id_User_Id_2827', 'User Id_User_Id_3238', 'User Id_User_Id_116', 'User Id_User_Id_744', 'User Id_User_Id_2851', 'Rider Id_Rider_Id_59', 'Rider Id_Rider_Id_305', 'User Id_User_Id_3020', 'Rider Id_Rider_Id_391', 'User Id_User_Id_3246', 'User Id_User_Id_3031', 'User Id_User_Id_1415', 'User Id_User_Id_1261', 'User Id_User_Id_2559', 'User Id_User_Id_3122', 'User Id_User_Id_105', 'User Id_User_Id_115', 'User Id_User_Id_2093', 'User Id_User_Id_1780', 'Rider Id_Rider_Id_677', 'User Id_User_Id_360', 'User Id_User_Id_3598', 'Rider Id_Rider_Id_373', 'User Id_User_Id_757', 'Rider Id_Rider_Id_802', 'User Id_User_Id_1648', 'User Id_User_Id_2199', 'User Id_User_Id_2762', 'User Id_User_Id_2...

# %%
X_data.head()

# %%
# Create the correlation matrix
corr = X_data.corr()

# Find rows and columns where correlation coefficients > 0.9 or <-0.9
corr[np.abs(corr) > 0.9]

# %%
# As before, we create the correlation matrix
# and find rows and columnd where correlation coefficients > 0.9 or <-0.9
corr = X_data.corr()
r, c = np.where(np.abs(corr) > 0.9)

# We are only interested in the off diagonal entries:
off_diagonal = np.where(r != c)

# Show the correlation matrix rows and columns where we have highly correlated off diagonal entries:
corr.iloc[r[off_diagonal], c[off_diagonal]]

# %%
DropColumns = ['Pickup - Weekday (Mo = 1)_5', 'Placement - Weekday (Mo = 1)_5','Placement - Weekday (Mo = 1)_5',
               'Confirmation - Weekday (Mo = 1)_5', 'Confirmation - Weekday (Mo = 1)_5', 'Confirmation - Weekday (Mo = 1)_2',
               'Pickup - Weekday (Mo = 1)_2','Pickup - Weekday (Mo = 1)_2', 'Placement - Weekday (Mo = 1)_2',
               'Placement - Weekday (Mo = 1)_2','Rider Id_Rider_Id_83','Confirmation - Day of Month','Confirmation - Day of Month',
               'Confirmation - Day of Month','Arrival at Pickup - Day of Month','Arrival at Pickup - Day of Month',
               'Arrival at Pickup - Day of Month','Pickup - Day of Month','Pickup - Day of Month',
               'Placement - Day of Month','Placement - Day of Month','Placement - Weekday (Mo = 1)_6',
               'Pickup - Weekday (Mo = 1)_6','Pickup - Weekday (Mo = 1)_6','Confirmation - Weekday (Mo = 1)_6',
               'Confirmation - Weekday (Mo = 1)_6']

# %%
X_data = X_data.drop(DropColumns,axis=1)
X_test_data = Test_df.drop(DropColumns, axis=1)

# %% [markdown]
# # Ensemble Method

# %% [markdown]
# **Feature Scaling**

# %%
# import the scaling module
from sklearn.preprocessing import StandardScaler

# %%
# create standardization object
scaler_X = StandardScaler()
scaler_y = StandardScaler()

# %%
columns = ['Distance (KM)', 'Destination Long','Pickup Long']
# save standardized features into new variable
X_data[columns] = scaler_X.fit_transform(X_data[columns])
y_data = np.array(y_data).reshape(-1,1)

# %% [markdown]
# **splitting features into test set and training set**

# %%
# import train/test split module
from sklearn.model_selection import train_test_split

# %%
# split dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_data,
                                                    y_data,
                                                    test_size=0.20,
                                                    random_state=1)

# %% [markdown]
# **Ridge Model**

# %%
from sklearn.linear_model import LinearRegression, Ridge

# %%
ridge = Ridge()
regressor = LinearRegression()

# %%
ridge.fit(X_train, y_train)
regressor.fit(X_train, y_train)

# %%
ridge_pred = ridge.predict(X_test)
regressor_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
ridge_rmse = mean_squared_error(y_test, ridge_pred, squared= False)
regressor_rmse = mean_squared_error(y_test, regressor_pred, squared= False)

# %%
ridge_rmse

# %%
regressor_rmse

# %% [markdown]
# Building Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
reg_tree = DecisionTreeRegressor(max_depth=3)

# %%
reg_tree.fit(X_train,y_train)
dt_pred = reg_tree.predict(X_test)

# %%
dt_rmse = mean_squared_error(y_test, dt_pred, squared= False)

# %%
dt_rmse

# %% [markdown]
# SVR Model

# %%
from sklearn.svm import SVR
sv_reg = SVR(kernel='rbf', gamma='auto')
sv_reg.fit(X_train,y_train)
svr_pred = sv_reg.predict(X_test)

# %%
svr_rmse = mean_squared_error(y_test, svr_pred, squared= False)

# %%
svr_rmse

# %% [markdown]
# Lasso Model

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha=0.01)
lasso.fit(X_train, y_train)
y_pred = lasso.predict(X_test)

# %%
lasso_rmse = mean_squared_error(y_test, y_pred, squared= False)
lasso_rmse

# %% [markdown]
# XGBoost model

# %%
from xgboost import XGBRegressor
xgb = XGBRegressor()
xgb.fit(X_train, y_train)

# %%
xgb_pred = xgb.predict(X_test)

# %%
xgb_rmse = mean_squared_error(y_test, y_pred, squared= False)

# %%
xgb_rmse

# %% [markdown]
# Stacking method

# %%
from sklearn.ensemble import StackingRegressor
models = [("LR",regressor),("DT",reg_tree),("SVR",sv_reg),("Ridge",ridge),("lasso",lasso),("xgb",xgb)]

# %%
meta_learner_reg = LinearRegression()
s_reg = StackingRegressor(estimators=models, final_estimator=meta_learner_reg)

# %%
s_reg.fit(X_train,y_train)

# %%
y_pred = s_reg.predict(X_test)

# %%
meta_rmse = mean_squared_error(y_test, y_pred, squared= False)
meta_rmse

# %%
s_reg.predict(X_test_data.drop(['Order No'],axis=1))
